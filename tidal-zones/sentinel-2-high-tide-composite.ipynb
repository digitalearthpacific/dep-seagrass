# %% [markdown]
# # High- and Low-tide Composites
#
# This notebook combines some of the lessons learnt in the first notebook
# and applies them to an analysis that seeks to create cloud-free mosaic
# images at either high or low tide. This can be helpful if you need to
# run an analysis such as identifying seagrass, which is more difficult
# when it's covered by water.

# %% [markdown]
# ## Install and preparation
#
# Download the Viti Levu tide model data using this code in a terminal:
#
# ```bash
# rm -rf ~/tide_models && \
# wget https://files.auspatious.com/coastlines/data/tide_models_fiji.zip -O /tmp/tide_models.zip && \
# unzip /tmp/tide_models.zip -d /tmp/tide_models_temp && \
# mv /tmp/tide_models_temp ~/tide_models
# ```
#
# And install some packages:
#
# ```bash
# pip install --upgrade pyTMD dea-tools
# ```

# %% [markdown]
# ### Package import
#
# First, we configure our Python package imports

# %%
from pystac_client import Client
from odc.stac import load
from dea_tools.coastal import pixel_tides

from dask.distributed import Client as DaskClient

from pathlib import Path
import odc.geo.xr  # noqa: F401
import folium
import rasterio

# %% [markdown]
# ### Configuration
#
# We're using the Element-84 STAC API to find Sentinel-2 data. This cell
# also sets up a Dask client, so that we can lazy-load data and process
# efficiently across multiple threads.
#
# If you click the link to the Dashboard, you should be able to watch Dask
# work, once we're at the stage where we compute the results.

# %%
# STAC Catalog URL
catalog = "https://earth-search.aws.element84.com/v1"

# Create a STAC Client
client = Client.open(catalog)

# Set up Dask
dask_client = DaskClient(n_workers=4, threads_per_worker=4)
dask_client
# Out:
# <Client: 'tcp://127.0.0.1:40317' processes=4 threads=16, memory=60.00 GiB>

# %% [markdown]
# ### Location and time
#
# This step sets up the spatial and temporal extents as well as configuring
# where the tide model is stored.

# %%
# Find a location you're interested in on Google Maps and copy the coordinates
# by right-clicking on the map and clicking the coordinates

# These coords are in the order Y then X, or Latitude then Longitude
coords = -18.175, 178.429  # Suva, Fiji
buffer = 0.1
bbox = (coords[1] - buffer, coords[0] - buffer, coords[1] + buffer, coords[0] + buffer)

datetime = "2023/2024"

# Tide data and config
home = Path("~")
tide_data_location = f"{home}/Data/tide_models_fiji"

# %% [markdown]
# ## Find and load data
#
# First, search the STAC API for Sentinel-2 scenes over our study site

# %%
items = client.search(
    collections=["sentinel-2-c1-l2a"],
    bbox=bbox,
    datetime=datetime
).item_collection()

print(f"Found {len(items)} STAC items")
# Out:
# Found 592 STAC items

# %% [markdown]
# ### Load
#
# Next, we use `odc-stac` to load data.

# %%
data = load(
    items,
    bands=["red", "green", "blue", "swir16", "cloud", "scl"],
    bbox=bbox,
    groupby="solar_day",
    chunks={"x": 2048, "y": 2048},
)

data
# Out:
# <xarray.Dataset> Size: 14GB
# Dimensions:      (y: 2231, x: 2134, time: 290)
# Coordinates:
#   * y            (y) float64 18kB 8.001e+06 8.001e+06 ... 7.979e+06 7.979e+06
#   * x            (x) float64 17kB 6.405e+05 6.405e+05 ... 6.618e+05 6.618e+05
#     spatial_ref  int32 4B 32760
#   * time         (time) datetime64[ns] 2kB 2023-01-01T22:30:52.805000 ... 202...
# Data variables:
#     red          (time, y, x) uint16 3GB dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     green        (time, y, x) uint16 3GB dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     blue         (time, y, x) uint16 3GB dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     swir16       (time, y, x) uint16 3GB dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     cloud        (time, y, x) uint8 1GB dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     scl          (time, y, x) uint8 1GB dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>

# %% [markdown]
# ### Cloud masking
#
# Masking out clouds is important, so that we can make a cloud-free mosaic
# using as many pixels as possible. In the previous example, we selected
# Landsat scenes that had less than a certain percentage of clouds. This method
# is good, but potentially loses valuable data by discarding the more cloudy
# scenes.

# %%
# 1: defective, 3: shadow, 8: med confidence cloud, 9: high confidence cloud
mask_flags = [0, 3, 8, 9]

cloud_mask = data.scl.isin(mask_flags)

masked = data.where(~cloud_mask).drop_vars("scl")

# %%
# Let's compare before and after

# Before
data[["red", "green", "blue"]].isel(time=1).to_array().plot.imshow(size=8, vmin=1000, vmax=4000)

# %%
# After
masked[["red", "green", "blue"]].isel(time=1).to_array().plot.imshow(size=8, vmin=1000, vmax=4000)

# %% [markdown]
# ### Tide modelling
#
# This next cell annotates the data with the height of the tide at
# the time the scene was captured. We use this information to select
# the scenes at the top and bottom 30% of tides.

# %%
tide_data_location = "~/tide_models/tide_models_fiji"

# %%
# Annotate the data with the tide height
tides_lowres = pixel_tides(
    masked, resample=False, directory=tide_data_location, model="FES2022", dask_compute=True
)
# Out:
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Modelling tides using FES2022 in parallel
# 100%|██████████| 5/5 [00:01<00:00,  2.62it/s]
# Returning low resolution tide array

# %%
lowest, highest = tides_lowres.quantile([0.3, 0.7]).values

low_scenes = tides_lowres.where(tides_lowres < lowest, drop=True)
high_scenes = tides_lowres.where(tides_lowres > highest, drop=True)

data_low = masked.sel(time=low_scenes.time)
data_high = masked.sel(time=high_scenes.time)

print(f"Found {len(data_low.time)} low tide days and {len(data_high.time)} high tide days out of {len(data.time)} days")
# Out:
# Found 89 low tide days and 89 high tide days out of 290 days

# %% [markdown]
# ## Compute and visualise
#
# This next cell creates a median of the high or low tide scenes. The
# function call `compute()` at the end tells Dask to do the work of
# downloading data and running the computation.

# %%
median_low = data_low.median("time").compute()
median_high = data_high.median("time").compute()
# Out:
# /srv/conda/envs/notebook/lib/python3.10/site-packages/rasterio/warp.py:387: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(
# /srv/conda/envs/notebook/lib/python3.10/site-packages/rasterio/warp.py:387: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(
# /srv/conda/envs/notebook/lib/python3.10/site-packages/rasterio/warp.py:387: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(
# 2025-01-13 02:20:42,404 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:44,078 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:45,528 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:47,260 - distributed.utils_perf - WARNING - full garbage collections took 38% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:48,837 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:49,756 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:50,568 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:51,025 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:51,824 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:52,438 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:53,272 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:53,922 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:54,476 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:55,237 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:55,342 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:56,590 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:56,705 - distributed.utils_perf - WARNING - full garbage collections took 39% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:56,743 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:57,591 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:58,349 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:58,961 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:59,295 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:20:59,356 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:00,082 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:00,476 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:00,850 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:01,980 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:02,125 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:02,156 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:02,320 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:03,789 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:03,838 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:04,147 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:04,202 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:05,270 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:06,063 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:06,373 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:06,398 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:06,943 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:08,014 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:08,087 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:08,161 - distributed.utils_perf - WARNING - full garbage collections took 37% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:08,763 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:09,594 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:09,768 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:10,150 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:10,867 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:11,005 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:11,704 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:13,050 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:14,754 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:16,827 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:17,252 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:17,324 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:19,107 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:19,203 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:19,243 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:19,379 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:20,826 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:20,981 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:21,500 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:21,961 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:22,438 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:23,249 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:23,331 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:23,419 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:24,249 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:24,371 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:24,407 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:25,409 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:25,946 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:25,962 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:26,143 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:27,360 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:27,398 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:27,604 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:27,948 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:29,108 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:29,185 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:29,347 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:29,810 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:30,744 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:31,022 - distributed.utils_perf - WARNING - full garbage collections took 25% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:32,179 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:32,507 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:32,687 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:33,907 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:33,907 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:34,050 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:34,789 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:35,390 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:35,647 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:35,745 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:36,379 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:37,249 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:37,386 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:38,242 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:38,258 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:39,272 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:39,849 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:40,034 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:40,183 - distributed.utils_perf - WARNING - full garbage collections took 32% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:41,443 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:41,795 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:41,905 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:42,024 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:42,778 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:43,350 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:43,702 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:44,521 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:45,072 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:45,347 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:45,395 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:46,298 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:47,149 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:47,182 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:47,563 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:47,980 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:49,135 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:49,218 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:49,338 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:50,550 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:50,781 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:50,905 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:51,383 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:52,341 - distributed.utils_perf - WARNING - full garbage collections took 24% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:52,649 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:52,968 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:53,121 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:53,911 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:54,236 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:54,909 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:55,129 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:55,982 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:56,789 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:56,993 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:57,163 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:58,137 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:58,380 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:58,574 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:21:59,081 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:22:00,274 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2025-01-13 02:22:00,346 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# 2025-01-13 02:22:00,781 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:22:02,023 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2025-01-13 02:22:02,104 - distributed.utils_perf - WARNING - full garbage collections took 30% CPU time recently (threshold: 10%)
# 2025-01-13 02:22:02,193 - distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)

# %% [markdown]
# ### Visualisation
#
# First we are going to visualise just the high-tide scene. If this looks
# good, the next step is to create an index, which will highlight areas that
# are likely to be land and water, and we can see the difference between
# low and high tide clearly. Each visualisation is done using an interactive
# map.

# %%
# Assuming median_low is an xarray.DataArray or xarray.Dataset
median_high.rio.to_raster(
    "south_suva_coast_high_tide.tif",
    driver="COG",
    compress="DEFLATE",  # Compression options, e.g., 'LZW', 'DEFLATE'
    dtype=rasterio.float32  # Ensure data type is correct
)

# %%
median_low.odc.explore(vmin=1000, vmax=4000)

# %%
median_high.odc.explore(vmin=1000, vmax=4000)

# %%
# Calculate MNDWI
median_low["mndwi"] = (median_low.green - median_low.swir16) / (median_low.green + median_low.swir16)
median_high["mndwi"] = (median_high.green - median_high.swir16) / (median_high.green + median_high.swir16)

# %%
# Plot LOW and HIGH MNDWI on the same map
m = folium.Map()

arguments = {
    "cmap": "RdBu",
    "vmin": -0.5,
    "vmax": 0.5,
}

# Plot each sample image with different colormap
median_low.mndwi.odc.add_to(m, name="low", **arguments)
median_high.mndwi.odc.add_to(m, name="high", **arguments)

folium.LayerControl().add_to(m)
m.fit_bounds(median_low.odc.map_bounds())
m
